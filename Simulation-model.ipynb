# %%
import pandas as pd
import pickle as pkl
from googletrans import Translator
translator = Translator()

# %%
dxy = pd.read_csv('./csv/DXYArea.csv')
with open('chineseProvince_to_EN.pkl','rb') as f:
    prov_dict = pkl.load(f)
with open('chineseCity_to_EN.pkl','rb') as f:
    city_dict = pkl.load(f)

# %%
dxy.head()
# Out:
#   provinceName cityName  province_confirmedCount  province_suspectedCount  \
# 0          陕西省       西安                      195                        0
# 1          陕西省       安康                      195                        0
# 2          陕西省       汉中                      195                        0
# 3          陕西省       咸阳                      195                        0
# 4          陕西省       宝鸡                      195                        0
#
#    province_curedCount  province_deadCount  city_confirmedCount  \
# 0                   17                   0                   88
# 1                   17                   0                   21
# 2                   17                   0                   21
# 3                   17                   0                   16
# 4                   17                   0                   12
#
#    city_suspectedCount  city_curedCount  city_deadCount  \
# 0                    0                9               0
# 1                    0                1               0
# 2                    0                0               0
# 3                    0                1               0
# 4                    0                2               0
#
#                 updateTime
# 0  2020-02-08 10:36:26.865
# 1  2020-02-08 10:36:26.865
# 2  2020-02-08 10:36:26.865
# 3  2020-02-08 10:36:26.865
# 4  2020-02-08 10:36:26.865

# %%
dxy.shape
# Out:
# (23997, 11)

# %%
def getProvinceTranslation(name):
    return prov_dict[name]
def getCityTranslation(name):
    return city_dict[name]

# %%
dxy['provinceName'] = dxy['provinceName'].apply(getProvinceTranslation)

# %%
dxy['cityName'] = dxy['cityName'].apply(getCityTranslation)

# %%
dxy.head()
# Out:
#        provinceName     cityName  province_confirmedCount  \
# 0  Shaanxi Province        Xi'an                      195
# 1  Shaanxi Province  Good health                      195
# 2  Shaanxi Province     Hanzhong                      195
# 3  Shaanxi Province     Xianyang                      195
# 4  Shaanxi Province        Baoji                      195
#
#    province_suspectedCount  province_curedCount  province_deadCount  \
# 0                        0                   17                   0
# 1                        0                   17                   0
# 2                        0                   17                   0
# 3                        0                   17                   0
# 4                        0                   17                   0
#
#    city_confirmedCount  city_suspectedCount  city_curedCount  city_deadCount  \
# 0                   88                    0                9               0
# 1                   21                    0                1               0
# 2                   21                    0                0               0
# 3                   16                    0                1               0
# 4                   12                    0                2               0
#
#                 updateTime
# 0  2020-02-08 10:36:26.865
# 1  2020-02-08 10:36:26.865
# 2  2020-02-08 10:36:26.865
# 3  2020-02-08 10:36:26.865
# 4  2020-02-08 10:36:26.865
